# %% [markdown]
# Welcome! This is a tutorial about RASpy (Reaction Activity Scores in Python).
# In this notebook, we will show how to compute the RAS matrix, using a gene count matrix and a metabolic model.

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load the metabolic model

# %%
from cobra.io import read_sbml_model
model=read_sbml_model('../metabolic_models/RECON3_ensg.xml')
model
# Out:
# <Model Recon3D at 0x1726b9c86a0>

# %% [markdown]
# Load the count matrix (h5ad format). Such a dataset are reported as TPM and was downloaded from the  EBI Single Cell Expression Atlas (https://www.ebi.ac.uk/gxa/sc/experiments/E-GEOD-86618/downloads)

# %%
import scanpy as sc
adata=sc.read_h5ad("../datasets/E-GEOD-86618_tpm")
adata
# Out:
# AnnData object with n_obs × n_vars = 540 × 23909
#     obs: 'Sample Characteristic[organism]', 'Sample Characteristic Ontology Term[organism]', 'Sample Characteristic[individual]', 'Sample Characteristic Ontology Term[individual]', 'Sample Characteristic[organism part]', 'Sample Characteristic Ontology Term[organism part]', 'Sample Characteristic[cell type]', 'Sample Characteristic Ontology Term[cell type]', 'Sample Characteristic[facs marker]', 'Sample Characteristic Ontology Term[facs marker]', 'Sample Characteristic[disease]', 'Sample Characteristic Ontology Term[disease]', 'Factor Value[single cell identifier]', 'Factor Value Ontology Term[single cell identifier]', 'Factor Value[disease]', 'Factor Value Ontology Term[disease]'

# %% [markdown]
# ## Compute RAS values

# %%
import sys
sys.path.insert(1, '../raspy/')

# %%
from ras import RAS_computation as rc

# %%
ras_object=rc(adata,model)

# %% [markdown]
# The default function used to evalute the OR and AND operators are the sum and the min function. In case of missing expression value in the count matrix, we remove such areferred to as NaN (Not a Number), for a gene joined with an AND operator in a given GPR rule, the user can choose to solve the rule ‘A AND NaN’ as A, or to disregard it tout-court (i.e., treated as NaN).

# %%
import numpy as np
import time
t0= time.time()
ras_adata=ras_object.compute(
                             or_expression=np.nansum,   #which operation for or_expression? default is np.nansum
                             and_expression=np.nanmin,  #which operation for and_expression? default is np.nanmin     
                             drop_na_rows=True,         #drop nan rows. Default is True
                             drop_duplicates=False      #drop duplicates values for ras.  Default is false
                            )
ras_adata

t1 = time.time()-t0
print("Time elapsed: ", t1) # CPU seconds elapsed (floating point)
# Out:
# 100%|#########################################################################|
# Time elapsed:  65.00678515434265

# %%
ras_adata.to_df()
# Out:
# REACTIONS    ATPS4mi  ATPasel_1  CYOOm2i  CYOR_u10mi     NDPK10n      NDPK1n  \
# SRR4216351  0.975053   7.255475      0.0    3.111485    0.000000    0.000000
# SRR4216352  1.061796   4.137387      0.0    0.813871    0.000000    0.000000
# SRR4216353  0.000000   0.000000      0.0    0.000000    0.000000    0.000000
# SRR4216354  0.000000   0.000000      0.0   11.344500  559.655457  559.655457
# SRR4216355  0.000000   0.000000      0.0    0.000000    0.000000    0.000000
# ...              ...        ...      ...         ...         ...         ...
# SRR4216886  0.000000   0.000000      0.0    0.000000    0.000000    0.000000
# SRR4216887  0.000000   0.000000      0.0    0.000000    0.000000    0.000000
# SRR4216888  0.000000   6.421671      0.0   11.331868   38.300667   38.300667
# SRR4216889  0.000000   0.000000      0.0    2.386348    0.000000    0.000000
# SRR4216890  0.000000  10.439538      0.0    0.000000    0.000000    0.000000
# SRR4216353                                                NaN
# SRR4216354                                                NaN
# SRR4216355                                                NaN
# ...                                                       ...
# SRR4216886                                                NaN
# SRR4216887                                                NaN
# SRR4216888                                                NaN
# SRR4216889                                                NaN
# SRR4216890                                                NaN
#
#            countmatrix_Factor Value[disease]  \
# SRR4216351                            normal
# SRR4216352                            normal
# SRR4216353     idiopathic pulmonary fibrosis
# SRR4216354     idiopathic pulmonary fibrosis
# SRR4216355                            normal
# ...                                      ...
# SRR4216886                            normal
# SRR4216887     idiopathic pulmonary fibrosis
# SRR4216888     idiopathic pulmonary fibrosis
# SRR4216889     idiopathic pulmonary fibrosis
# SRR4216890     idiopathic pulmonary fibrosis
#
#            countmatrix_Factor Value Ontology Term[disease]
# SRR4216351     http://purl.obolibrary.org/obo/PATO_0000461
# SRR4216352     http://purl.obolibrary.org/obo/PATO_0000461
# SRR4216353            http://www.ebi.ac.uk/efo/EFO_0000768
# SRR4216354            http://www.ebi.ac.uk/efo/EFO_0000768
# SRR4216355     http://purl.obolibrary.org/obo/PATO_0000461
# ...                                                    ...
# SRR4216886     http://purl.obolibrary.org/obo/PATO_0000461
# SRR4216887            http://www.ebi.ac.uk/efo/EFO_0000768
# SRR4216888            http://www.ebi.ac.uk/efo/EFO_0000768
# SRR4216889            http://www.ebi.ac.uk/efo/EFO_0000768
# SRR4216890            http://www.ebi.ac.uk/efo/EFO_0000768
#
# [540 rows x 16 columns]

# %%
ras_adata.var
# Out:
#                                                    common_gprs compartments  \
# REACTIONS
# ATPS4mi                                                ATPS4mi          i,m
# ATPasel_1                                            ATPasel_1          c,l
# CYOOm2i                                                CYOOm2i          i,m
# CYOR_u10mi                                          CYOR_u10mi          i,m
# NDPK10n      NDPK10n,NDPK1n,NDPK2n,NDPK3n,NDPK4n,NDPK5n,NDP...            n
# ...                                                        ...          ...
# SR5ARr                                                  SR5ARr            r
# BILDGLCURte                                        BILDGLCURte          c,e
# SPHS1Pt2e                                            SPHS1Pt2e          c,e
# G6PPer                                                  G6PPer            r
# NAPRT                                                    NAPRT            c
#
#                                                       GPR rule
# REACTIONS
# ATPS4mi      ( ( ENSG00000099624 and ENSG00000152234 and EN...
# ATPasel_1    ( ( ENSG00000105929 and ENSG00000117410 and EN...
# CYOOm2i      ( ENSG00000010256 and ENSG00000173660 and ENSG...
# CYOR_u10mi   ( ENSG00000010256 and ENSG00000173660 and ENSG...
# NDPK10n      ( ENSG00000011052 and ENSG00000239672 ) or ( E...
# ...                                                        ...
# SR5ARr                      ENSG00000277893 or ENSG00000145545
# BILDGLCURte  ENSG00000278183 or ENSG00000023839 or ENSG0000...
# SPHS1Pt2e                   ENSG00000278183 or ENSG00000165029
# G6PPer       ENSG00000278373 or ENSG00000131482 or ENSG0000...
# NAPRT                       ENSG00000278488 or ENSG00000103485
#
# [5566 rows x 3 columns]

# %% [markdown]
# ## Save the results

# %%
from scipy.sparse import csr_matrix
ras_adata.X = csr_matrix(ras_adata.X)

# %%
ras_adata.write("../datasets/E-GEOD-86618_ras_adata")
# Out:
# ... storing 'common_gprs' as categorical
# ... storing 'compartments' as categorical
# ... storing 'GPR rule' as categorical
